# %%
import requests
import lxml.html as lh
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import re

# %%
#url='https://www.houstontx.gov/police/news.htm'
url='https://www.houstontx.gov/police/nr/2019/dec/index.htm'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
soup = BeautifulSoup(page.text, 'lxml')
gdp = soup.find_all("table", attrs={"class": "default"})
print("Number of tables on site: ",len(gdp))
# Out:
# Number of tables on site:  1

# %%
table1 = gdp[0]
body = table1.find_all("tr")
# Head values (Column names) are the first items of the body list
head = body[0] # 0th item is the header row
body_rows = body[1:] # All other items becomes the rest of the rows

# Lets now iterate through the head HTML code and make list of clean headings

# Declare empty list to keep Columns names
headings = []
for item in head.find_all("th"): # loop through all th elements
    # convert the th elements to text and strip "\n"
    item = (item.text).rstrip("\n")
    # append the clean column name to headings
    headings.append(item)
print(headings)
# Next is now to loop though the rest of the rows

#print(body_rows[0])
all_rows = [] # will be a list for list for all rows
for row_num in range(len(body_rows)): # A row at a time
    row = [] # this will old entries for one row
    for row_item in body_rows[row_num].find_all("td"): #loop through all row entries
        # row_item.text removes the tags from the entries
        # the following regex is to remove \xa0 and \n and comma from row_item.text
        # xa0 encodes the flag, \n is the newline and comma separates thousands in numbers
        aa = re.sub("(\xa0)|(\n)|,","",row_item.text)
        #append aa to row - note one row entry is being appended
        row.append(aa)
    # append one row to all_rows
    all_rows.append(row)
df = pd.DataFrame(data=all_rows,columns=['data','event'])
df.head()
# Out:
# ['\nDecember 2019']
#        data                                              event
# 0  12-31-19  Investigation Into Fatal Shooting At 9601 West...
# 1  12-31-19  Investigation Into Two Women Found Deceased At...
# 2  12-31-19  Investigation Into Fatal Crash At 6100 West Li...
# 3  12-30-19  Investigation Into Fatal Shooting At 5021 Long...
# 4  12-30-19  Investigation Into Fatal Shooting At 1000 Cros...

# %%
df.shape
# Out:
# (102, 2)

# %%
# Filter out other types of events cause we only focus on fatal shooting and crash.
df = df[df['event'].str.contains("Fatal")]
df.shape
# Out:
# (58, 2)

# %%
df['address'] = np.nan
for i in range(len(df)):
    df.iloc[i,2] = ''.join(re.findall('(?<=At ).*$',df.iloc[i,1])) + ", Houston, TX, USA" 
df.head()
# Out:
#        data                                              event  \
# 0  12-31-19  Investigation Into Fatal Shooting At 9601 West...
# 2  12-31-19  Investigation Into Fatal Crash At 6100 West Li...
# 3  12-30-19  Investigation Into Fatal Shooting At 5021 Long...
# 4  12-30-19  Investigation Into Fatal Shooting At 1000 Cros...
# 7  12-30-19  Investigation Into Fatal Crash At 8200 Telepho...
#
#                                         address
# 0   9601 West Montgomery Road, Houston, TX, USA
# 2  6100 West Little York Road, Houston, TX, USA
# 3      5021 Longmeadow Street, Houston, TX, USA
# 4          1000 Crosby Street, Houston, TX, USA
# 7         8200 Telephone Road, Houston, TX, USA

# %%
df['event_type'] = "Fatal Crash"
df.iloc[df['event'].str.contains("Shooting"),3] = "Fatal Shooting"
df.head()
# Out:
#        data                                              event  \
# 0  01-31-20    Investigation into Fatal Crash at 610 Sunnyside
# 1  01-31-20  Investigation into Fatal Shooting at 9202 Nath...
# 2  01-31-20  Investigation into Fatal Shooting at 800 South...
# 3  01-31-20  Investigation into Fatal Shooting at 9002 Ster...
# 5  01-31-20  Investigation into Fatal Shooting at 3600 Yose...
#
#                                        address      event_type
# 0              610 Sunnyside, Houston, TX, USA     Fatal Crash
# 1      9202 Nathaniel Street, Houston, TX, USA  Fatal Shooting
# 2    800 South Wayside Drive, Houston, TX, USA  Fatal Shooting
# 3  9002 Sterlingshire Street, Houston, TX, USA  Fatal Shooting
# 5       3600 Yosemite Street, Houston, TX, USA  Fatal Shooting

# %%
df.to_csv(r"C:\Users\Fate\Downloads\ML\HPD\Dec2019_address.csv",index=False)

# %%
import glob
import os
os.chdir(r"C:\Users\Fate\Downloads\ML\HPD")
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
all_filenames
# Out:
# ['Apr2020_address.csv',
#  'Apr2021_address.csv',
#  'Apr2022_address.csv',
#  'Aug2020_address.csv',
#  'Aug2021_address.csv',
#  'Aug2022_address.csv',
#  'Dec2020_address.csv',
#  'Dec2021_address.csv',
#  'Feb2020_address.csv',
#  'Feb2021_address.csv',
#  'Feb2022_address.csv',
#  'Jan2020_address.csv',
#  'Jan2021_address.csv',
#  'Jan2022_address.csv',
#  'Jul2020_address.csv',
#  'Jul2021_address.csv',
#  'Jul2022_address.csv',
#  'Jun2020_address.csv',
#  'Jun2021_address.csv',
#  'Jun2022_address.csv',
#  'Mar2020_address.csv',
#  'Mar2021_address.csv',
#  'Mar2022_address.csv',
#  'May2020_address.csv',
#  'May2021_address.csv',
#  'May2022_address.csv',
#  'Nov2020_address.csv',
#  'Nov2021_address.csv',
#  'Oct2020_address.csv',
#  'Oct2021_address.csv',
#  'Oct2022_address.csv',
#  'Sep2020_address.csv',
#  'Sep2021_address.csv',
#  'Sep2022_address.csv']

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined.csv", index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv(r"C:\Users\Fate\Downloads\ML\HPD\combined.csv")
df = df.iloc[:,1:]
df.head(30)
# Out:
#         data                                              event  \
# 0   04-30-20  Investigation into Fatal Crash at 5800 Eastex ...
# 1   04-28-20  Investigation into Fatal Crash at 4300 Telepho...
# 2   04-28-20  Investigation into Fatal Shooting at 3826 Seab...
# 3   04-27-20  Investigation into Fatal Shooting at 8301 Darl...
# 4   04-27-20  Investigation into Fatal Crash at 11100 Almeda...
# 5   04-27-20  Investigation into Fatal Shooting at 10615 Mea...
# 6   04-24-20  Investigation into Fatal Shooting at 4600 Whit...
# 7   04-24-20  Investigation into Fatal Shooting at 4714 Ward...
# 8   04-24-20  Investigation into Fatal Shooting at 8900 Sout...
# 9   04-23-20  Investigation into Fatal Crash at 6000 Nunn St...
# 10  04-23-20  Investigation into Fatal Shooting at 10115 Lea...
# 11  04-23-20  Investigation into Fatal Shooting at 7445 Calh...
# 12  04-22-20  Investigation into Fatal Shooting at 12201 Bee...
# 13  04-21-20  Investigation into Fatal Crash at 7600 Cullen ...
# 14  04-20-20  Investigation into Fatal Shooting at 17510 Way...
# %%
df.shape
# Out:
# (1513, 4)

# %%
import geopy
import geopandas
from geopy.geocoders import GoogleV3,Nominatim
locator = Nominatim(user_agent="myGeocoder")

geolocator = GoogleV3(api_key = "Your_API_Key_here")

# %%
location = geolocator.geocode("My office address, Houston, USA")
print("Latitude = {}, Longitude = {}".format(location.latitude, location.longitude))
# Out:
# Latitude = 29.544439, Longitude = -95.5702195

# %%
latitude=[]
longitude=[]
for address in df['address']:
    latitude.append(geolocator.geocode(address).latitude)
    longitude.append(geolocator.geocode(address).longitude)
print(len(latitude))
df['latitude'] = latitude
df['longitude'] = longitude
df.head()
# Out:
# 200

# %%
df.head()
# Out:
#        data                                              event  \
# 0  04-30-20  Investigation into Fatal Crash at 5800 Eastex ...
# 1  04-28-20  Investigation into Fatal Crash at 4300 Telepho...
# 2  04-28-20  Investigation into Fatal Shooting at 3826 Seab...
# 3  04-27-20  Investigation into Fatal Shooting at 8301 Darl...
# 4  04-27-20  Investigation into Fatal Crash at 11100 Almeda...
#
#                                    address      event_type   latitude  \
# 0    5800 Eastex Freeway, Houston, TX, USA     Fatal Crash  29.812368
# 1    4300 Telephone Road, Houston, TX, USA     Fatal Crash  29.702930
# 2   3826 Seabrook Street, Houston, TX, USA  Fatal Shooting  29.684594
# 3  8301 Darlington Drive, Houston, TX, USA  Fatal Shooting  29.834904
# 4      11100 Almeda Road, Houston, TX, USA     Fatal Crash  29.662690
#
#    longitude
# 0 -95.331982
# 1 -95.304678
# 2 -95.366678
# 3 -95.275063
# 4 -95.400054

# %%
df['road_name'] = np.nan
df.head()
# Out:
#    Unnamed: 0      data                                              event  \
# 0           0  04-30-20  Investigation into Fatal Crash at 5800 Eastex ...
# 1           1  04-28-20  Investigation into Fatal Crash at 4300 Telepho...
# 2           2  04-28-20  Investigation into Fatal Shooting at 3826 Seab...
# 3           3  04-27-20  Investigation into Fatal Shooting at 8301 Darl...
# 4           4  04-27-20  Investigation into Fatal Crash at 11100 Almeda...
#
#                                    address      event_type   latitude  \
# 0    5800 Eastex Freeway, Houston, TX, USA     Fatal Crash  29.812368
# 1    4300 Telephone Road, Houston, TX, USA     Fatal Crash  29.702930
# 2   3826 Seabrook Street, Houston, TX, USA  Fatal Shooting  29.684594
# 3  8301 Darlington Drive, Houston, TX, USA  Fatal Shooting  29.834904
# 4      11100 Almeda Road, Houston, TX, USA     Fatal Crash  29.662690
#
#    longitude                   road  road_name
# 0 -95.331982    5800 Eastex Freeway        NaN
# 1 -95.304678    4300 Telephone Road        NaN
# 2 -95.366678   3826 Seabrook Street        NaN
# 3 -95.275063  8301 Darlington Drive        NaN
# 4 -95.400054      11100 Almeda Road        NaN

# %%
for i in range(len(dfAll)):
    df.iloc[i,8] = ' '.join(df.iloc[i,7].split(" ")[1:])
df.head()
# Out:
#    Unnamed: 0      data                                              event  \
# 0           0  04-30-20  Investigation into Fatal Crash at 5800 Eastex ...
# 1           1  04-28-20  Investigation into Fatal Crash at 4300 Telepho...
# 2           2  04-28-20  Investigation into Fatal Shooting at 3826 Seab...
# 3           3  04-27-20  Investigation into Fatal Shooting at 8301 Darl...
# 4           4  04-27-20  Investigation into Fatal Crash at 11100 Almeda...
#
#                                    address      event_type   latitude  \
# 0    5800 Eastex Freeway, Houston, TX, USA     Fatal Crash  29.812368
# 1    4300 Telephone Road, Houston, TX, USA     Fatal Crash  29.702930
# 2   3826 Seabrook Street, Houston, TX, USA  Fatal Shooting  29.684594
# 3  8301 Darlington Drive, Houston, TX, USA  Fatal Shooting  29.834904
# 4      11100 Almeda Road, Houston, TX, USA     Fatal Crash  29.662690
#
#    longitude                   road         road_name
# 0 -95.331982    5800 Eastex Freeway    Eastex Freeway
# 1 -95.304678    4300 Telephone Road    Telephone Road
# 2 -95.366678   3826 Seabrook Street   Seabrook Street
# 3 -95.275063  8301 Darlington Drive  Darlington Drive
# 4 -95.400054      11100 Almeda Road       Almeda Road

# %%
from geopy.geocoders import Nominatim, GoogleV3
  
# initialize Nominatim API 
locator = Nominatim(user_agent="geoapiExercises", timeout=None)
geolocator = GoogleV3(api_key = "Your_API_Key_here")
  
# place input by geek
place = "5500 North Freeway, Houston, TX, USA"
location = locator.geocode(place)
  
# traverse the data
data = location.raw
# print(str(geolocator.geocode(place)).split(",")[2].split(" ")[2])
loc_data = data['display_name'].split()
print("Full Location")
print(loc_data)
print("Zip code : ",loc_data[-3])
# Out:
# Full Location
# ['North', 'Freeway,', 'Houston,', 'Harris', 'County,', 'Texas,', '77022,', 'United', 'States']
# Zip code :  77022,

# %%
zip = []
for i in df['address']:
    if locator.geocode(i) == None:
        zip.append("00000")
    else:
        zip.append(locator.geocode(i).raw['display_name'].split()[-3][:5])
df['zip'] = zip
# Out:
# 200

# %%
df.head()
# Out:
#        data                                              event  \
# 0  04-30-20  Investigation into Fatal Crash at 5800 Eastex ...
# 1  04-28-20  Investigation into Fatal Crash at 4300 Telepho...
# 2  04-28-20  Investigation into Fatal Shooting at 3826 Seab...
# 3  04-27-20  Investigation into Fatal Shooting at 8301 Darl...
# 4  04-27-20  Investigation into Fatal Crash at 11100 Almeda...
#
#                                    address      event_type   latitude  \
# 0    5800 Eastex Freeway, Houston, TX, USA     Fatal Crash  29.812368
# 1    4300 Telephone Road, Houston, TX, USA     Fatal Crash  29.702930
# 2   3826 Seabrook Street, Houston, TX, USA  Fatal Shooting  29.684594
# 3  8301 Darlington Drive, Houston, TX, USA  Fatal Shooting  29.834904
# 4      11100 Almeda Road, Houston, TX, USA     Fatal Crash  29.662690
#
#    longitude                   road         road_name    zip
# 0 -95.331982    5800 Eastex Freeway    Eastex Freeway  77026
# 1 -95.304678    4300 Telephone Road    Telephone Road  77087
# 2 -95.366678   3826 Seabrook Street   Seabrook Street  77021
# 3 -95.275063  8301 Darlington Drive  Darlington Drive  77028
# 4 -95.400054      11100 Almeda Road       Almeda Road  77021

# %%
df.to_csv(r"C:\Users\Fate\Downloads\ML\HPD\df3years.csv",index=False)
